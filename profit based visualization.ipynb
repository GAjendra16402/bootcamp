# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("C:\\Users\\gajendra singh\\OneDrive\\Desktop\\pandas\\archive (1)\\Amazon Sale Report.csv")
# Out:
# C:\Users\gajendra singh\AppData\Local\Temp\ipykernel_14612\924610547.py:1: DtypeWarning: Columns (23) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("C:\\Users\\gajendra singh\\OneDrive\\Desktop\\pandas\\archive (1)\\Amazon Sale Report.csv")

# %%
df.head()
# Out:
#    index             Order ID      Date                        Status  \
# 0      0  405-8078784-5731545  04-30-22                     Cancelled
# 1      1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2      2  404-0687676-7273146  04-30-22                       Shipped
# 3      3  403-9615377-8133951  04-30-22                     Cancelled
# 4      4  407-1069790-7240320  04-30-22                       Shipped
#
#   Fulfilment Sales Channel  ship-service-level    Style              SKU  \
# 0   Merchant      Amazon.in           Standard   SET389   SET389-KR-NP-S
# 1   Merchant      Amazon.in           Standard  JNE3781  JNE3781-KR-XXXL
# 2     Amazon      Amazon.in          Expedited  JNE3371    JNE3371-KR-XL
# 3   Merchant      Amazon.in           Standard    J0341       J0341-DR-L
# 4     Amazon      Amazon.in          Expedited  JNE3671  JNE3671-TU-XXXL
#
#         Category  ... currency  Amount    ship-city   ship-state  \
# ...

# %%
df = df.drop(columns = ['Unnamed: 23','index'], axis =1)

# %%
df
# Out:
#                    Order ID      Date                        Status  \
# 0       405-8078784-5731545  04-30-22                     Cancelled
# 1       171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2       404-0687676-7273146  04-30-22                       Shipped
# 3       403-9615377-8133951  04-30-22                     Cancelled
# 4       407-1069790-7240320  04-30-22                       Shipped
# ...                     ...       ...                           ...
# 128970  406-6001380-7673107  05-31-22                       Shipped
# 128971  402-9551604-7544318  05-31-22                       Shipped
# 128972  407-9547469-3152358  05-31-22                       Shipped
# 128973  402-6184140-0545956  05-31-22                       Shipped
# 128974  408-7436540-8728312  05-31-22                       Shipped
#
#        Fulfilment Sales Channel  ship-service-level    Style              SKU  \
# ...

# %%
df = df.fillna(0)

# %%
df.isnull().sum()
# Out:
# Order ID              0
# Date                  0
# Status                0
# Fulfilment            0
# Sales Channel         0
# ship-service-level    0
# Style                 0
# SKU                   0
# Category              0
# Size                  0
# ASIN                  0
# Courier Status        0
# Qty                   0
# currency              0
# Amount                0
# ship-city             0
# ship-state            0
# ship-postal-code      0
# ship-country          0
# promotion-ids         0
# B2B                   0
# fulfilled-by          0
# dtype: int64

# %%
df.head()
# Out:
#               Order ID      Date                        Status Fulfilment  \
# 0  405-8078784-5731545  04-30-22                     Cancelled   Merchant
# 1  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer   Merchant
# 2  404-0687676-7273146  04-30-22                       Shipped     Amazon
# 3  403-9615377-8133951  04-30-22                     Cancelled   Merchant
# 4  407-1069790-7240320  04-30-22                       Shipped     Amazon
#
#   Sales Channel  ship-service-level    Style              SKU       Category  \
# 0      Amazon.in           Standard   SET389   SET389-KR-NP-S            Set
# 1      Amazon.in           Standard  JNE3781  JNE3781-KR-XXXL          kurta
# 2      Amazon.in          Expedited  JNE3371    JNE3371-KR-XL          kurta
# 3      Amazon.in           Standard    J0341       J0341-DR-L  Western Dress
# 4      Amazon.in          Expedited  JNE3671  JNE3671-TU-XXXL            Top
#
# ...

# %%
total_sales = df['Amount'].sum()
print(total_sales)
# Out:
# 78592678.29999998

# %%
sales_category = df.groupby('Category')['Amount'].sum()
sales_category
# Out:
# Category
# Blouse             458408.18
# Bottom             150667.98
# Dupatta               915.00
# Ethnic Dress       791217.66
# Saree              123933.76
# Set              39204124.03
# Top               5347792.30
# Western Dress    11216072.69
# kurta            21299546.70
# Name: Amount, dtype: float64

# %%
sales_state = df.groupby('ship-state')['Amount'].sum()
sales_state.head()
# Out:
# ship-state
# 0                       18671.00
# ANDAMAN & NICOBAR      158723.62
# ANDHRA PRADESH        3219831.72
# APO                         0.00
# AR                        493.00
# Name: Amount, dtype: float64

# %%
df['ship-state'].info()
# Out:
# <class 'pandas.core.series.Series'>
# RangeIndex: 128975 entries, 0 to 128974
# Series name: ship-state
# Non-Null Count   Dtype
# --------------   -----
# 128975 non-null  object
# dtypes: object(1)
# memory usage: 1007.7+ KB

# %%
total_orders = df.shape[0]

# %%
total_orders
# Out:
# 128975

# %%
higher_order=sales_state.idxmax()

# %%
higher_order
# Out:
# 'MAHARASHTRA'

# %%
top_selling = df.groupby('Category')['Amount'].sum().nlargest(5)

# %%
top_selling
# Out:
# Category
# Set              39204124.03
# kurta            21299546.70
# Western Dress    11216072.69
# Top               5347792.30
# Ethnic Dress       791217.66
# Name: Amount, dtype: float64
